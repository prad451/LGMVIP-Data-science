# %% [markdown]
# # Name: Pradnya Salve

# %% [markdown]
# # Task-1

# %% [markdown]
# # Iris Flowers Classification ML Project

# %% [markdown]
# **Importing liabraries**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %% [markdown]
# **Loading the data**

# %%
iris_data = pd.read_csv("C:\\Users\\icon\\Desktop\\ML_TE\\dataset\\Iris.csv")

# %%
iris_data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# **Printing information about dataframe**

# %%
iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
iris_data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# **Printing first five rows of the dataset**

# %%
iris_data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# **Printing last five rows of the dataset**

# %%
iris_data.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %% [markdown]
# **To print number of samples belongs to each species**

# %%
iris_data['Species'].value_counts()
# Out:
# Iris-virginica     50
# Iris-versicolor    50
# Iris-setosa        50
# Name: Species, dtype: int64

# %% [markdown]
# **To print number of rows and columns**

# %%
iris_data.shape
# Out:
# (150, 6)

# %% [markdown]
# **To print data types of each column**

# %%
iris_data.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %% [markdown]
# **To print the null values in the dataset**

# %%
iris_data.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %% [markdown]
# **To print number of null values**

# %%
iris_data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# **Displaying all columns of dataset**

# %%
iris_data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %% [markdown]
# **Correlation between the variables**

# %%
iris_data.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %% [markdown]
# # Data visualization

# %% [markdown]
# **Scatter plot**

# %%
colors = ['blue','red','orange']
Species = ['Iris-setosa','Iris-versicolor','Iris-virginica']

# %%
for i in range(3):
    x = iris_data[iris_data['Species'] == Species[i]]
    plt.scatter(x['SepalLengthCm'],x['SepalWidthCm'],c = colors[i],label = Species[i])
    plt.xlabel('Sepal Length')
    plt.ylabel('Sepal Width')
    plt.legend()

# %%
colors = ['red','purple','green']
Species = ['Iris-setosa','Iris-versicolor','Iris-virginica']

# %%
for i in range(3):
    x = iris_data[iris_data['Species'] == Species[i]]
    plt.scatter(x['PetalLengthCm'],x['PetalWidthCm'],c = colors[i],label = Species[i])
    plt.xlabel('Petal Length')
    plt.ylabel('Petal Width')
    plt.legend()

# %% [markdown]
# **Bar plot**

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.barplot(x= 'Species',y = 'SepalLengthCm', data = iris_data)
plt.subplot(2,2,2)
sns.barplot(x= 'Species',y = 'PetalLengthCm', data = iris_data)
plt.subplot(2,2,3)
sns.barplot(x= 'Species',y = 'SepalWidthCm', data = iris_data)
plt.subplot(2,2,4)
sns.barplot(x= 'Species',y = 'PetalWidthCm', data = iris_data)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalWidthCm'>

# %% [markdown]
# **Box plot**

# %%
sns.boxplot(x= 'Species',y = 'SepalLengthCm', data = iris_data)
plt.show()

# %%
sns.boxplot(x= 'Species',y = 'SepalWidthCm', data = iris_data)
plt.show()

# %%
sns.boxplot(x= 'Species',y = 'PetalLengthCm', data = iris_data)
plt.show()

# %%
sns.boxplot(x= 'Species',y = 'PetalWidthCm', data = iris_data)
plt.show()

# %% [markdown]
# **Violin plot**

# %%
sns.violinplot(y='Species', x='SepalLengthCm', data=iris_data, inner='quartile')
plt.show()
sns.violinplot(y='Species', x='SepalWidthCm', data=iris_data, inner='quartile')
plt.show()
sns.violinplot(y='Species', x='PetalLengthCm', data=iris_data, inner='quartile')
plt.show()
sns.violinplot(y='Species', x='PetalWidthCm', data=iris_data, inner='quartile')
plt.show()

# %% [markdown]
# **Count plot for number of species**

# %%
sns.countplot(x = 'Species', data = iris_data)
plt.show()

# %% [markdown]
# **Pair plot**

# %%
sns.pairplot(iris_data.drop('Id',axis=1), hue='Species', data=iris_data, kind='scatter')
plt.show()

# %% [markdown]
# **Histogram**

# %%
iris_data= iris_data.drop('Id',axis=1)
iris_data.hist(figsize=(12,12))
plt.show()

# %% [markdown]
# **Heatmap**

# %%
plt.figure(figsize=(7,5))
sns.heatmap(iris_data.corr(), annot=True, cmap='PiYG')
plt.show()

# %% [markdown]
# **Splitting the dataset**

# %%
from sklearn.model_selection import train_test_split
iris_data= iris_data.drop('Id',axis=1)
x = iris_data.values[:,0:4]
y = iris_data.values[:,4]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3,random_state= 1)

# %%
len(x_train)
# Out:
# 105

# %%
len(x_test)
# Out:
# 45

# %% [markdown]
# # Training the model

# %% [markdown]
# **Support Vector Machine**

# %%
model = SVC()
model.fit(x_train,y_train)
predictions = model.predict(x_test)
print(accuracy_score(y_test, predictions))
# Out:
# 0.9777777777777777

# %% [markdown]
# # THANK YOU
